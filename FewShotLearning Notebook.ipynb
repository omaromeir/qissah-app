# %% [markdown]
# ## watsonx API connection
# This cell defines the credentials required to work with watsonx API for Foundation
# Model inferencing.
#
# **Action:** Provide the IBM Cloud personal API key. For details, see
# <a href="https://cloud.ibm.com/docs/account?topic=account-userapikey&interface=ui" target="_blank">documentation</a>.

# %%
import os
import getpass

def get_credentials():
	return {
		"url" : "https://eu-de.ml.cloud.ibm.com",
		"apikey" : getpass.getpass("n_mMMf-M68fePv4tTMw5OgipRtv4tB1HLdMeOaf16GRL")
	}

# %%
model_id = "sdaia/allam-1-13b-instruct" #Defining the model id

project_id = "07954e26-b0dd-45e4-a22f-0ae8e0a8593a" #Defining the project id

# %%
#Defining the model parameters
parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 4096,
    "repetition_penalty": 1.11
}

# %%
# Defining the Model object
from ibm_watsonx_ai.foundation_models import ModelInference
model = ModelInference(
    model_id=model_id,
    params=parameters,
    credentials=get_credentials(),
    project_id=project_id,  
   # space_id=space_id
)
# Out:
# n_mMMf-M68fePv4tTMw5OgipRtv4tB1HLdMeOaf16GRL ········

# %%
#Prompt Lab input

prompt_input = """Check the examples of how the story should look based on the user input. Using the examples below, write a short Arabic story relevant to Arabic culture for kids aged 8-11.
When writing the story, use the following details provided by the child: Type of characters, Number of characters, Character names, Story setting, Main theme. 

Repeat the information provided for clarity. Then, write the story and think it through step by step. Ensure it has a clear beginning, middle, and end. Each time, finish with a unique conclusion: Happy Ending, Bittersweet Conclusion, Surprise Ending, Cliffhanger, or Humorous Ending.
Add a fitting title. don't add a note. 

Input: موضوع القصة: عواقب الكذب وأهمية الصدق
نوع الشخصيات: بشر وحيوانات
عدد الشخصيات: الراعي، أهل القرية، الذئب
مكان القصة: قرية وحقول الرعي
الموضوع الرئيسي أو المغزى الأخلاقي: أهمية الصدق وعواقب الكذب المتكرر، قصة شعبية
Output: قصة الراعي الكذاب 

يُروى أنه في أحد الأزمنة كان راعٍ يسكن في قرية يتصف سكانها بالكرم والصدق والأمانة وحب مساعدة الآخرين، ولكن الراعي لم يتصف بهذه الأخلاق الكريمة، بل كان مخادعًا ويحب افتعال المشاكل من أجل التسلية، وفي أحد الأيام في الصباح الباكر وهو جالس في المرعى ويشعر بالضجر، جاءته فكرة، فقام يصيح بأعلى صوته أنجدوني الذئب يأكل أغنامي، وظل يكرر حتى استيقظ كل من في القرية وجاء ليساعده، ولما وصلوا للمرعى، وجود الراعي جالس بين أغنامه، ويضحك ويقول لهم لقد خدعتكم. استنكر أهل القرية فعله، وأخبروه أن خداع الناس وإفزاعهم ليس مضحكاً ولا مسلياً، لم يلقِ الراعي بالًا لكلام أهل القرية، وكرر فعلته في اليومين التاليين، حتى ضجر الناس من فعله وقرروا أن لا يستجيب له مرة أخرى، وفي اليوم الرابع وبينما كان الراعي جالساً في المرعى، وإذا بذئب قد انقض على أغنامه وبدأ بذبحها واحدة تلو الأخرى، فصاح الراعي يطلب النجدة من أهل القرية، ولكن دون جدوى فقد خدعهم ثلاث مرات، ولن يصدقوه اليوم عندما جاء الذئب.


Input: نوع الشخصيات: بشر
عدد الشخصيات: 3
أسماء الشخصيات: أحمد، أم أحمد، أصدقاء أحمد
مكان القصة: حي سكني
الموضوع الرئيسي أو المغزى الأخلاقي: قول الصدق أفضل من الكذب حتى في المواقف الصعبة
Output: أحمد وزجاجة العصير 

أحمد طفل جميل ومجتهد ويُساعد أمه في كلّ شيء، ويجلب لها ما تحتاجه من أغراضٍ مختلفة، وكان دائمًا يُحبّ اللعب والمرح، وفي أحد الأيام احتاجت أم أحمد علبة من العصير كي تقدم منها للضيوف، فطلبت من أحمد أن يذهب لشراء هذه العلبة بسرعة من البقالة المجاورة، وحذّرته من اللعب في الطريق حتى لا تقع منه الزجاجة وتنكسر.  أخذ أحمد النقود من أمه وتوجّه إلى الدكان القريب كي يشتري العصير، وفي الطريق رأى مجموعة من أصدقائه يلعبون في الطريق ويمرحون وهم يضربون كرة القدم بأرجلهم وكانت أصوات ضحكاتهم عالية تدلّ على المرح، فشعر أحمد برغبة كبيرة في اللعب معهم على الرغم من تحذير أمه باللعب ومعه زجاجة العصير. فيديو قد يعجبك: نسي أحمد كلام أمه ووضع زجاجة العصير جانبًا، وبدأ باللعب مع أصدقائه بالكرة، وفجأة أثناء اللعب صدمت الكرة بزجاجة العصير وتسببت بسقوطها على الأرض وانكسارها، فانسكب العصير كله على الأرض، فبدأ أحمد بالبكاء وهو لا يعرف ماذا سيقول لأمه، فتجمع حوله أصدقاؤه وطلبوا منه أن يقول لأمه إنّ زجاجة العصير وقعت منه وحدها ولم تصطدم بها كرة القدم. لكن أحمد لم يتعوّد الكذب على أمه، وقرّر أن يقول لها الصدق مهما حدث، وأن يُصارحها بالحقيقة كما هي، وعندما وصل أحمد إلى البيت سألته أمه عن زجاجة العصير، فأخبرها بالحقيقة، وعلى الرغم من أنّ زجاجة العصير قد تكسّرت لأن أحمد لم يسمع كلام أمه إلّا أنها لم تغضب منه لأن أمين وقال الصدق ولم تعاقبه.

Input: نوع الشخصيات: بشر وكائنات سحرية
عدد الشخصيات: 8
أسماء الشخصيات: سندريلا، زوجة الأب، الأختان، الأب، الأمير، كبير الحرس، المرأة السحرية (طيف الأم)
مكان القصة: منزل عائلي، قصر ملكي
الموضوع الرئيسي أو المغزى الأخلاقي: سندريلا في ثيابها الرثة، العربة السحرية، سندريلا في فستان الحفلة، الحذاء الزجاجي، الأمير يبحث عن صاحبة الحذاء
Output: قصة ساندريلا


كان هناك رجل نبيل تزوج بعد وفاة زوجته الأولى من امرأة متكبرة وقاسية، لها ابنتان تحملان طباعها السيئة. كانت سندريلا، ابنة الرجل، طيبة ورقيقة. بدأت زوجة الأب تظهر كراهيتها لسندريلا بسبب جمالها وطيبتها، وأجبرتها على القيام بكل الأعمال المنزلية الشاقة، وأعطتها ملابس رثة، بينما دللت ابنتيها وقدمت لهما أفضل الطعام وأجمل الثياب.

وصلت دعوة من قصر الملك إلى جميع فتيات البلدة لحضور حفلة الأمير. منعت زوجة الأب سندريلا من الذهاب، فجلست تبكي حتى ظهر طيف أمها الراحلة ووعدتها بمساعدتها. بأعجوبة سحرية، حولت الأم اليقطينة إلى عربة والفئران إلى خيول، وألبست سندريلا فستانًا فاخرًا وحذاءً زجاجيًا، مع تحذير بالعودة قبل منتصف الليل.

أبهرت سندريلا الجميع في الحفلة، وجلس الأمير بجانبها طوال الوقت. ومع دق الساعة الثانية عشرة، غادرت مسرعة وفقدت فردة من حذائها. أمر الأمير الحرس بالبحث عن صاحبة الحذاء، وزاروا جميع البيوت حتى وصلوا إلى بيت سندريلا. حاولت الأختان منعها من القياس، لكن الحرس أصر، فدخل الحذاء قدمها بسلاسة. أخرجت سندريلا الفردة الثانية، وظهرت أمها الطيف مرة أخرى وأعادت إليها فستانها الفاخر.

عادت سندريلا مع الحرس إلى القصر، وتزوجت الأمير في حفل مهيب. سامحت أختيها ودعتهما للعيش في القصر، حيث زُوّجتا من كبار موظفي البلاط الملكي، وعاش الجميع بسعادة.

Input: نوع الشخصيات: حيوان
عدد الشخصيات: ٣
أسماء الشخصيات: أبرار، سيرين، ياسمين
مكان القصة: المنزل
الموضوع الرئيسي أو المغزى الأخلاقي: منزل في مزرعة

Output:"""

# %%
#Execution using the defined Model object and pairin it with input and generate the response:

print("Submitting generation request...")
generated_response = model.generate_text(prompt=prompt_input, guardrails=False)
print(generated_response)
# Out:
# Submitting generation request...
#  مغامرات أبرار وسيرين وياسمين
#
# في إحدى المزارع الجميلة، عاشت ثلاث صديقات مقربات: أبرار، سيرين، وياسمين. كن يقضين معظم أوقاتهن معًا في استكشاف المزرعة والتعرف على الحيوانات المختلفة التي تعيش فيها.
#
# في يوم من الأيام، قررت الصديقات الثلاث تنظيم رحلة استكشافية داخل الغابة القريبة من المزرعة. وأثناء تجوالهن، عثرن على كهف غامض لم يسبق لهن رؤيته من قبل. أثارت الفضول أبرار وقررت الدخول لاستكشاف الكهف.
#
# بينما كانت أبرار تستكشف الكهف، وجدت نفسها أمام باب مغلق بإحكام. حاولت فتحه لكنها فشلت. فجأة، سمعت صوتًا غريبًا يأتي من خلف الباب. شعرت بالخوف والتردد، لكنها تذكرت نصيحة سيرين بأن تكون شجاعة وتتبع قلبها.
#
# قررت أبرار فتح الباب بحذر شديد، وما إن فعلت ذلك حتى رأت مفاجأة مذهلة! وجدت حديقة جميلة مليئة بالزهور الملونة والفواكه اللذيذة. أدركت أبرار أن الحديقة ليست طبيعية وأنها نتيجة لعمل سحري.
#
# ...

# %% [markdown]
# # Next steps
# You successfully completed this notebook! You learned how to use
# watsonx.ai inferencing SDK to generate response from the foundation model
# based on the provided input, model id and model parameters. Check out the
# official watsonx.ai site for more samples, tutorials, documentation, how-tos, and blog posts.
#
# <a id="copyrights"></a>
# ### Copyrights
#
# Licensed Materials - Copyright © 2023 IBM. This notebook and its source code are released under the terms of the ILAN License.
# Use, duplication disclosure restricted by GSA ADP Schedule Contract with IBM Corp.
#
# **Note:** The auto-generated notebooks are subject to the International License Agreement for Non-Warranted Programs (or equivalent) and License Information document for watsonx.ai Auto-generated Notebook (License Terms), such agreements located in the link below. Specifically, the Source Components and Sample Materials clause included in the License Information document for Watson Studio Auto-generated Notebook applies to the auto-generated notebooks.
#
# By downloading, copying, accessing, or otherwise using the materials, you agree to the <a href="https://www14.software.ibm.com/cgi-bin/weblap/lap.pl?li_formnum=L-AMCU-BYC7LF" target="_blank">License Terms</a>
